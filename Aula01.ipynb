# %% [markdown]
# # Introdução ao Python

# %%
print('Olá mundo!')
# Out:
# Olá mundo!

# %%
'Olá mundo!'
# Out:
# 'Olá mundo!'

# %%
1+1
# Out:
# 2

# %%
10-4
# Out:
# 6

# %%
#Comentários
#Multiplicação
2*2
# Out:
# 4

# %%
frase = 'Introdução ao Python'

# %%
print(frase[0])
print(frase[10:])
print(frase[:10])
print(frase.count('o'))
# Out:
# I
#  ao Python
# Introdução
# 4

# %%
print(frase.lower())
print(frase.upper())
# Out:
# introdução ao python
# INTRODUÇÃO AO PYTHON

# %%
frase.replace('Python','Java')
# Out:
# 'Introdução ao Java'

# %%
frase
# Out:
# 'Introdução ao Python'
